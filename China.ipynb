# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("GlobalLandTemperaturesByCountry.csv", index_col=0, header=0,  parse_dates=True, squeeze=True)
china1=df[(df.Country == 'China')]
china=china1.drop("AverageTemperatureUncertainty", axis=1)
data_chi_year = china.groupby([china.index.year]).mean()
data_smooth=data_chi_year.ewm(com=5).mean()
plt.figure(figsize=(20,5),facecolor=None)
ax=plt.axes()
plt.xlabel('Years')
plt.ylabel('Average temperature')
ax.set_facecolor("#AAAAAA")
plt.plot(data_smooth,"#001f3f",linewidth=2,label="SmoothData")
plt.plot(data_chi_year,"#3D9970" ,linewidth=1,label="AbsoluteData")
plt.legend()
plt.show()

# %%
df = pd.read_csv("GlobalLandTemperaturesByCountry.csv", index_col=0, header=0,  parse_dates=True, squeeze=True)
india1=df[(df.Country == 'India')]
india=india1.drop("AverageTemperatureUncertainty", axis=1)
data_ind_year = india.groupby([india.index.year]).mean()
data_smooth=data_ind_year.ewm(com=5).mean()
plt.figure(figsize=(20,5),facecolor=None)
ax=plt.axes()
plt.xlabel('Years')
plt.ylabel('Average temperature')
ax.set_facecolor("#AAAAAA")
plt.plot(data_smooth,"#001f3f",linewidth=2,label="SmoothData")
plt.plot(data_ind_year,"#3D9970" ,linewidth=1,label="AbsoluteData")
plt.legend()
plt.show()

# %%
df = pd.read_csv("GlobalLandTemperaturesByCountry.csv", index_col=0, header=0,  parse_dates=True, squeeze=True)
azerbaijan=df[(df.Country == 'Azerbaijan')]
aze=azerbaijan.drop("AverageTemperatureUncertainty", axis=1)
data_aze_year = aze.groupby([aze.index.year]).mean()
data_smooth=data_aze_year.ewm(com=5).mean()
plt.figure(figsize=(20,5),facecolor=None)
ax=plt.axes()
plt.xlabel('Years')
plt.ylabel('Average temperature')
ax.set_facecolor("#AAAAAA")
plt.plot(data_smooth,"#001f3f",linewidth=2,label="SmoothData")
plt.plot(data_aze_year,"#3D9970" ,linewidth=1,label="AbsoluteData")
plt.legend()
plt.show()
